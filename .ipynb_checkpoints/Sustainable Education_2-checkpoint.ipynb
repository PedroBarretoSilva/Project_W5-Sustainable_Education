# %% [markdown]
# # SUSTAINABLE EDUCATION

# %%
#importing the required Libraries


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import r2_score
import math


import pymysql
from sqlalchemy import create_engine

from getpass import getpass

# %%
#importing the dataframes

grades_region = pd.read_excel('grades.xlsx')
districts = pd.read_excel('districts.xlsx')
coastal = pd.read_excel('coastal.xlsx')

# %%
#Visualizing the raw data

# %%
grades_region.head()
# Out:
#     Contexto Ranking                                             Escola  \
# 0  Favorável    16.º  Escola Artística de Música do Conservatório Na...
# 1  Favorável    32.º  Escola Artística do Conservatório de Música Ca...
# 2  Favorável    37.º                        Escola Básica Vasco da Gama
# 3  Favorável    38.º    Escola Básica e Secundária da Quinta das Flores
# 4  Favorável    40.º                 Escola Secundária Infanta D. Maria
#
#   Concelho  Média
# 0   Lisboa   4.07
# 1    Braga   3.94
# 2   Lisboa   3.92
# 3  Coimbra   3.92
# 4  Coimbra   3.91

# %%
print(grades_region.shape)
# Out:
# (1119, 5)

# %%
districts.head()
# Out:
#           District / Name of municipality[a] Area (km2)  Area rank[b]  \
# 0  Autonomous region                     NaN        NaN           NaN
# 1             Aveiro      Albergaria-a-Velha      155.4         196.0
# 2             Aveiro      Oliveira do Bairro       87.3         260.0
# 3             Aveiro          Vale de Cambra      146.5         204.0
# 4             Aveiro                  Águeda      335.3          89.0
#
#    Pop. total (2011)[c]  Pop. rank[b]  PD (per km2 in 2011)[c]  PD rank[b]  \
# 0                   NaN           NaN                      NaN         NaN
# 1                25.497          99.0                    164.0        83.0
# 2                22.365         115.0                    256.0        59.0
# 3                24.761         103.0                    169.0        80.0
# 4                49.691          58.0                    148.0        91.0
#
#    Number of parishes[1] Ruling party 2017-2021[d][e]
# 0                    NaN                          NaN
# 1                    6.0                          CDS
# 2                    4.0                          CDS
# 3                    7.0                          CDS
# 4                   11.0                          IND

# %%
districts.shape
# Out:
# (311, 10)

# %%
coastal.head()
# Out:
#   District     Geog
# 0   Lisboa  Coastal
# 1    Porto  Coastal
# 2    Braga  Coastal
# 3  Setúbal  Coastal
# 4   Aveiro  Coastal

# %%
coastal.shape
# Out:
# (18, 2)

# %% [markdown]
# # CLEANING THE DATA

# %% [markdown]
# # 1 - Dropping unnecessary columns and choosing better names

# %%
districts_2 = districts[['District /','Name of municipality[a]']]

districts_2 = districts_2.rename(columns={'District /': 'District','Name of municipality[a]': 'Municipality'})


districts_2
# Out:
#               District        Municipality
# 0    Autonomous region                 NaN
# 1               Aveiro  Albergaria-a-Velha
# 2               Aveiro  Oliveira do Bairro
# 3               Aveiro      Vale de Cambra
# 4               Aveiro              Águeda
# ..                 ...                 ...
# 306              Viseu               Viseu
# 307              Viseu             Vouzela
# 308              Viseu               Nelas
# 309              Viseu        Castro Daire
# 310              Viseu             Tabuaço
#
# [311 rows x 2 columns]

# %%
grades_region = grades_region.rename (columns={'Contexto':'Context','Escola':'School','Concelho':'Municipality','Média':'Grade'})

grades_region
# Out:
#         Context Ranking                                             School  \
# 0     Favorável    16.º  Escola Artística de Música do Conservatório Na...
# 1     Favorável    32.º  Escola Artística do Conservatório de Música Ca...
# 2     Favorável    37.º                        Escola Básica Vasco da Gama
# 3     Favorável    38.º    Escola Básica e Secundária da Quinta das Flores
# 4     Favorável    40.º                 Escola Secundária Infanta D. Maria
# ...         ...     ...                                                ...
# 1114    Privado      -                                  Colégio São Filipe
# 1115    Privado      -                                   Colégio D. Filipa
# 1116    Privado      -                   Instituto Jacob Rodrigues Pereira
# 1117    Privado      -              Colégio Maria Pia (Casa Pia de Lisboa)
# 1118    Privado      -                     Colégio D. Nuno Álvares Pereira
#
#      Municipality  Grade
# 0          Lisboa   4.07
# 1           Braga   3.94
# 2          Lisboa   3.92
# 3         Coimbra   3.92
# 4         Coimbra   3.91
# ...           ...    ...
# 1114      Setúbal   2.30
# 1115      Amadora   2.25
# 1116       Lisboa   2.25
# 1117       Lisboa   2.19
# 1118       Lisboa   2.13
#
# [1119 rows x 5 columns]

# %%
coastal = coastal.rename (columns={'Geog':'Region'})

coastal
# Out:
#             District       Region
# 0             Lisboa      Coastal
# 1              Porto      Coastal
# 2              Braga      Coastal
# 3            Setúbal      Coastal
# 4             Aveiro      Coastal
# 5             Leiria      Coastal
# 6           Santarém      Coastal
# 7            Coimbra      Coastal
# 8               Faro      Coastal
# 9              Viseu  Non-Coastal
# 10  Viana do Castelo  Non-Coastal
# 11         Vila Real  Non-Coastal
# 12    Castelo Branco  Non-Coastal
# 13            Guarda  Non-Coastal
# 14             Évora  Non-Coastal
# 15              Beja  Non-Coastal
# 16          Bragança  Non-Coastal
# 17        Portalegre  Non-Coastal

# %% [markdown]
# # 2 - Cleanning the NAN

# %%
# 2.1 - checking the % of NAN on each column
# 2.1.1 - dataset: districts_2

# %%
districts_2.shape
# Out:
# (311, 2)

# %%
round(districts_2.isna().sum()/len(districts_2),4)*100
# Out:
# District        0.64
# Municipality    0.96
# dtype: float64

# %%
# very few NAN. we have more than 300 rows, and the %NAN is similar for both columns  (likely top be related)
# so is worth to get rid of those lines with NAN

# %%
districts_2 = districts_2.dropna()

districts_2
# Out:
#     District        Municipality
# 1     Aveiro  Albergaria-a-Velha
# 2     Aveiro  Oliveira do Bairro
# 3     Aveiro      Vale de Cambra
# 4     Aveiro              Águeda
# 5     Aveiro              Anadia
# ..       ...                 ...
# 306    Viseu               Viseu
# 307    Viseu             Vouzela
# 308    Viseu               Nelas
# 309    Viseu        Castro Daire
# 310    Viseu             Tabuaço
#
# [307 rows x 2 columns]

# %%
round(districts_2.isna().sum()/len(districts_2),4)*100   # all NAN cleaned  !
# Out:
# District        0.0
# Municipality    0.0
# dtype: float64

# %%
# 2.1.2 - dataset: grades_region

# %%
grades_region.shape
# Out:
# (1119, 5)

# %%
round(grades_region.isna().sum()/len(grades_region),4)*100
# Out:
# Context         28.87
# Ranking          0.27
# School           0.00
# Municipality     0.00
# Grade            0.00
# dtype: float64

# %%
# For the column "Context" we have a significant % of NAN (28,87%).

# %%
grades_region['Context'].value_counts(dropna=False)
# Out:
# NaN             323
# Favorável       313
# Desfavorável    297
# Privado         186
# Name: Context, dtype: int64

# %%
# The NAN are related with situations where the conext is "Normal" (neither Favourable or unfavourable. 
# This way, we can replace the NAN by "Normal"

# %%
grades_region['Context']=grades_region['Context'].fillna('Normal')

grades_region
# Out:
#         Context Ranking                                             School  \
# 0     Favorável    16.º  Escola Artística de Música do Conservatório Na...
# 1     Favorável    32.º  Escola Artística do Conservatório de Música Ca...
# 2     Favorável    37.º                        Escola Básica Vasco da Gama
# 3     Favorável    38.º    Escola Básica e Secundária da Quinta das Flores
# 4     Favorável    40.º                 Escola Secundária Infanta D. Maria
# ...         ...     ...                                                ...
# 1114    Privado      -                                  Colégio São Filipe
# 1115    Privado      -                                   Colégio D. Filipa
# 1116    Privado      -                   Instituto Jacob Rodrigues Pereira
# 1117    Privado      -              Colégio Maria Pia (Casa Pia de Lisboa)
# 1118    Privado      -                     Colégio D. Nuno Álvares Pereira
#
#      Municipality  Grade
# 0          Lisboa   4.07
# 1           Braga   3.94
# 2          Lisboa   3.92
# 3         Coimbra   3.92
# 4         Coimbra   3.91
# ...           ...    ...
# 1114      Setúbal   2.30
# 1115      Amadora   2.25
# 1116       Lisboa   2.25
# 1117       Lisboa   2.19
# 1118       Lisboa   2.13
#
# [1119 rows x 5 columns]

# %%
grades_region['Context'].value_counts(dropna=False)
# Out:
# Normal          323
# Favorável       313
# Desfavorável    297
# Privado         186
# Name: Context, dtype: int64

# %%
# About the column ranking: we have more than 1000 rows, so we can drop the rows whith NAN in the raking column (only 0,27%)

grades_region = grades_region.dropna()

grades_region
# Out:
#         Context Ranking                                             School  \
# 0     Favorável    16.º  Escola Artística de Música do Conservatório Na...
# 1     Favorável    32.º  Escola Artística do Conservatório de Música Ca...
# 2     Favorável    37.º                        Escola Básica Vasco da Gama
# 3     Favorável    38.º    Escola Básica e Secundária da Quinta das Flores
# 4     Favorável    40.º                 Escola Secundária Infanta D. Maria
# ...         ...     ...                                                ...
# 1114    Privado      -                                  Colégio São Filipe
# 1115    Privado      -                                   Colégio D. Filipa
# 1116    Privado      -                   Instituto Jacob Rodrigues Pereira
# 1117    Privado      -              Colégio Maria Pia (Casa Pia de Lisboa)
# 1118    Privado      -                     Colégio D. Nuno Álvares Pereira
#
#      Municipality  Grade
# 0          Lisboa   4.07
# 1           Braga   3.94
# 2          Lisboa   3.92
# 3         Coimbra   3.92
# 4         Coimbra   3.91
# ...           ...    ...
# 1114      Setúbal   2.30
# 1115      Amadora   2.25
# 1116       Lisboa   2.25
# 1117       Lisboa   2.19
# 1118       Lisboa   2.13
#
# [1116 rows x 5 columns]

# %%
round(grades_region.isna().sum()/len(grades_region),4)*100   # all NAN cleaned  !
# Out:
# Context         0.0
# Ranking         0.0
# School          0.0
# Municipality    0.0
# Grade           0.0
# dtype: float64

# %%
# 3 - removing the strings ".º" and "-"

# %%
grades_region['Ranking']=grades_region['Ranking'].str.replace('.º','') 
#grades_region['Ranking']=grades_region['Ranking'].str.replace('-','') 
grades_region['Ranking']=grades_region['Ranking'].str.replace(' ','-') 
grades_region
# Out:
# C:\Users\pbsil\AppData\Local\Temp/ipykernel_528/4619273.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   grades_region['Ranking']=grades_region['Ranking'].str.replace('.º','')
# C:\Users\pbsil\AppData\Local\Temp/ipykernel_528/4619273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grades_region['Ranking']=grades_region['Ranking'].str.replace('.º','')
# C:\Users\pbsil\AppData\Local\Temp/ipykernel_528/4619273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grades_region['Ranking']=grades_region['Ranking'].str.replace(' ','-')
#         Context Ranking                                             School  \
# 0     Favorável      16  Escola Artística de Música do Conservatório Na...
# 1     Favorável      32  Escola Artística do Conservatório de Música Ca...
# 2     Favorável      37                        Escola Básica Vasco da Gama
# 3     Favorável      38    Escola Básica e Secundária da Quinta das Flores
# 4     Favorável      40                 Escola Secundária Infanta D. Maria
# ...         ...     ...                                                ...
# 1114    Privado      -                                  Colégio São Filipe
# 1115    Privado      -                                   Colégio D. Filipa
# 1116    Privado      -                   Instituto Jacob Rodrigues Pereira
# 1117    Privado      -              Colégio Maria Pia (Casa Pia de Lisboa)
# 1118    Privado      -                     Colégio D. Nuno Álvares Pereira
#
#      Municipality  Grade
# 0          Lisboa   4.07
# 1           Braga   3.94
# 2          Lisboa   3.92
# 3         Coimbra   3.92
# 4         Coimbra   3.91
# ...           ...    ...
# 1114      Setúbal   2.30
# 1115      Amadora   2.25
# 1116       Lisboa   2.25
# 1117       Lisboa   2.19
# 1118       Lisboa   2.13
#
# [1116 rows x 5 columns]

# %% [markdown]
# # Exporting the tables to SQL and CSV

# %%
# 1) Choosing the best order for the columns before exporting them (first column = key)

# %%
districts_2 = districts_2[['Municipality','District']]
districts_2
# Out:
#            Municipality District
# 1    Albergaria-a-Velha   Aveiro
# 2    Oliveira do Bairro   Aveiro
# 3        Vale de Cambra   Aveiro
# 4                Águeda   Aveiro
# 5                Anadia   Aveiro
# ..                  ...      ...
# 306               Viseu    Viseu
# 307             Vouzela    Viseu
# 308               Nelas    Viseu
# 309        Castro Daire    Viseu
# 310             Tabuaço    Viseu
#
# [307 rows x 2 columns]

# %%
grades_region = grades_region[['School','Context','Municipality','Grade']]
grades_region
# Out:
#                                                  School    Context  \
# 0     Escola Artística de Música do Conservatório Na...  Favorável
# 1     Escola Artística do Conservatório de Música Ca...  Favorável
# 2                           Escola Básica Vasco da Gama  Favorável
# 3       Escola Básica e Secundária da Quinta das Flores  Favorável
# 4                    Escola Secundária Infanta D. Maria  Favorável
# ...                                                 ...        ...
# 1114                                 Colégio São Filipe    Privado
# 1115                                  Colégio D. Filipa    Privado
# 1116                  Instituto Jacob Rodrigues Pereira    Privado
# 1117             Colégio Maria Pia (Casa Pia de Lisboa)    Privado
# 1118                    Colégio D. Nuno Álvares Pereira    Privado
#
#      Municipality  Grade
# 0          Lisboa   4.07
# 1           Braga   3.94
# 2          Lisboa   3.92
# 3         Coimbra   3.92
# 4         Coimbra   3.91
# ...           ...    ...
# 1114      Setúbal   2.30
# 1115      Amadora   2.25
# 1116       Lisboa   2.25
# 1117       Lisboa   2.19
# 1118       Lisboa   2.13
#
# [1116 rows x 4 columns]

# %%
coastal
# Out:
#             District       Region
# 0             Lisboa      Coastal
# 1              Porto      Coastal
# 2              Braga      Coastal
# 3            Setúbal      Coastal
# 4             Aveiro      Coastal
# 5             Leiria      Coastal
# 6           Santarém      Coastal
# 7            Coimbra      Coastal
# 8               Faro      Coastal
# 9              Viseu  Non-Coastal
# 10  Viana do Castelo  Non-Coastal
# 11         Vila Real  Non-Coastal
# 12    Castelo Branco  Non-Coastal
# 13            Guarda  Non-Coastal
# 14             Évora  Non-Coastal
# 15              Beja  Non-Coastal
# 16          Bragança  Non-Coastal
# 17        Portalegre  Non-Coastal

# %%
# exporting the data to a SQL database

# %%
password=getpass()    # safe password to access the database
# Out:
# ········

# %%
# creatimg the database "Educação" in the SQL server

connection_string = 'mysql+pymysql://root:'+password+'@localhost/educacao'
engine=create_engine(connection_string)

# %%
# creating the tables in the database Educação: districts_2 , grades_region , coastal

districts_2.to_sql(con=engine, name='municipality', if_exists='replace', index=False) 
grades_region.to_sql(con=engine, name='school', if_exists='replace', index=False) 
coastal.to_sql(con=engine, name='districts', if_exists='replace', index=False)

# %%
# creating a backup of the tables in a csv file

districts_2.to_csv('municipality.csv', index=False)
grades_region.to_csv('school.csv', index=False)
coastal.to_csv('districts.csv', index=False)

# %% [markdown]
# # IMPORTING A SUMMARY TABLE FROM AN SQL DATABASE

# %%
query= 'SELECT * FROM educacao.school JOIN educacao.municipality USING (Municipality) JOIN educacao.districts USING (District);'

cleaned_dada = pd.read_sql_query(query,engine)
cleaned_dada
# Out:
#      District Municipality                                             School  \
# 0      Lisboa       Lisboa  Escola Artística de Música do Conservatório Na...
# 1       Braga        Braga  Escola Artística do Conservatório de Música Ca...
# 2      Lisboa       Lisboa                        Escola Básica Vasco da Gama
# 3     Coimbra      Coimbra    Escola Básica e Secundária da Quinta das Flores
# 4     Coimbra      Coimbra                 Escola Secundária Infanta D. Maria
# ...       ...          ...                                                ...
# 1106  Setúbal      Setúbal                                 Colégio São Filipe
# 1107   Lisboa      Amadora                                  Colégio D. Filipa
# 1108   Lisboa       Lisboa                  Instituto Jacob Rodrigues Pereira
# 1109   Lisboa       Lisboa             Colégio Maria Pia (Casa Pia de Lisboa)
# 1110   Lisboa       Lisboa                    Colégio D. Nuno Álvares Pereira
#
#         Context  Grade   Region
# 0     Favorável   4.07  Coastal
# 1     Favorável   3.94  Coastal
# 2     Favorável   3.92  Coastal
# 3     Favorável   3.92  Coastal
# 4     Favorável   3.91  Coastal
# ...         ...    ...      ...
# 1106    Privado   2.30  Coastal
# 1107    Privado   2.25  Coastal
# 1108    Privado   2.25  Coastal
# 1109    Privado   2.19  Coastal
# 1110    Privado   2.13  Coastal
#
# [1111 rows x 6 columns]

# %%
# Questions:

# Does economic health of a family impact the children´s school grades?
# Children from non-costal regions have lower grades?
# Is there a relationship between a school´s ranking and the average grades of its students?

# %%
# ensuring that the column Ranking becomes integer

# grades_region['Ranking'].value_counts(dropna=False)




# grades_region.dtypes


# converting the Ranking into an integer


# pd.to_numeric(grades_region['Ranking'], errors='coerce')
#grades_region['Ranking']=grades_region['Ranking'].fillna('NA')

# grades_region





# grades_region['Ranking'].value_counts(dropna=False)
